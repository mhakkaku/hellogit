# %%
#kaggleTitanic

# %%
#必要なライブラリのインポート
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

# %%
# ファイルはこのnotebookと同じディレクトリを
import pandas as pd
# csvファイルとして保存してある場合はこちらを利用
df_train = pd.read_csv('./Downloads/train.csv')
df_test=pd.read_csv('./Downloads/test.csv')

# %%
#trainデータの確認
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#testデータの確認
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
#データの欠損について確認
df_train.isnull()
# Out:
#     PassengerId Survived Pclass   Name    Sex    Age  SibSp  Parch Ticket  \
# 0         False    False  False  False  False  False  False  False  False
# 1         False    False  False  False  False  False  False  False  False
# 2         False    False  False  False  False  False  False  False  False
# 3         False    False  False  False  False  False  False  False  False
# 4         False    False  False  False  False  False  False  False  False
# 5         False    False  False  False  False   True  False  False  False
# 6         False    False  False  False  False  False  False  False  False
# 7         False    False  False  False  False  False  False  False  False
# 8         False    False  False  False  False  False  False  False  False
# 9         False    False  False  False  False  False  False  False  False
# 10        False    False  False  False  False  False  False  False  False
# 11        False    False  False  False  False  False  False  False  False
# ...

# %%
df_train["Age"].fillna(df_train.Fare.mean(), inplace=True)
df_train["Fare"].fillna(df_train.Fare.mean(), inplace=True)

# %%
#性別はダミー変数化
pd.get_dummies(df_train['Sex'])
df_sex=pd.get_dummies(df_train['Sex'])
df_sex.head()
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %%
#Embarked(乗船場所)もダミー変数化
pd.get_dummies(df_train['Embarked'])
df_embarked=pd.get_dummies(df_train['Embarked'])
df_embarked.head()
# Out:
#    C  Q  S
# 0  0  0  1
# 1  1  0  0
# 2  0  0  1
# 3  0  0  1
# 4  0  0  1

# %%
df_train=pd.concat([df_train,df_embarked],axis=1)
df_4 = df_train.drop('Embarked', axis=1)
df_train=df_4
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df_train=pd.concat([df_train,df_sex],axis=1)
df_3 = df_train.drop('Sex', axis=1)
df_train=df_3
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
combine1 = [df_train]

for train in combine1: 
        train['Salutation'] = train.Name.str.extract(' ([A-Za-z]+).', expand=False) 
for train in combine1: 
        train['Salutation'] = train['Salutation'].replace(['Lady', 'Countess','Capt', 'Col','Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
        train['Salutation'] = train['Salutation'].replace('Mlle', 'Miss')
        train['Salutation'] = train['Salutation'].replace('Ms', 'Miss')
        train['Salutation'] = train['Salutation'].replace('Mme', 'Mrs')
        del train['Name']
Salutation_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5} 
for train in combine1: 
        train['Salutation'] = train['Salutation'].map(Salutation_mapping) 
        train['Salutation'] = train['Salutation'].fillna(0)

# %%
for train in combine1: 
        train['Ticket_Lett'] = train['Ticket'].apply(lambda x: str(x)[0])
        train['Ticket_Lett'] = train['Ticket_Lett'].apply(lambda x: str(x)) 
        train['Ticket_Lett'] = np.where((train['Ticket_Lett']).isin(['1', '2', '3', 'S', 'P', 'C', 'A']), train['Ticket_Lett'], np.where((train['Ticket_Lett']).isin(['W', '4', '7', '6', 'L', '5', '8']), '0','0')) 
        train['Ticket_Len'] = train['Ticket'].apply(lambda x: len(x)) 
        del train['Ticket'] 
train['Ticket_Lett']=train['Ticket_Lett'].replace("1",1).replace("2",2).replace("3",3).replace("0",0).replace("S",3).replace("P",0).replace("C",3).replace("A",3)

# %%
for train in combine1: 
    train['Cabin_Lett'] = train['Cabin'].apply(lambda x: str(x)[0]) 
    train['Cabin_Lett'] = train['Cabin_Lett'].apply(lambda x: str(x)) 
    train['Cabin_Lett'] = np.where((train['Cabin_Lett']).isin([ 'F', 'E', 'D', 'C', 'B', 'A']),train['Cabin_Lett'], np.where((train['Cabin_Lett']).isin(['W', '4', '7', '6', 'L', '5', '8']), '0','0'))
del train['Cabin'] 
train['Cabin_Lett']=train['Cabin_Lett'].replace("A",1).replace("B",2).replace("C",1).replace("0",0).replace("D",2).replace("E",2).replace("F",1)

# %%
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
for train in combine1:
    train['IsAlone'] = 0
    train.loc[train['FamilySize'] == 1, 'IsAlone'] = 1

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  C  Q  S  \
# 0            1         0       3  22.0      1      0   7.2500  0  0  1
# 1            2         1       1  38.0      1      0  71.2833  1  0  0
# 2            3         1       3  26.0      0      0   7.9250  0  0  1
# 3            4         1       1  35.0      1      0  53.1000  0  0  1
# 4            5         0       3  35.0      0      0   8.0500  0  0  1
#
#    female  male  Salutation  Ticket_Lett  Ticket_Len  Cabin_Lett  FamilySize  \
# 0       0     1         1.0            3           9           0           2
# 1       1     0         3.0            0           8           1           2
# 2       1     0         2.0            3          16           0           1
# 3       1     0         3.0            1           6           1           2
# 4       0     1         1.0            3           6           0           1
#
#    IsAlone
# 0        0
# 1        0
# 2        1
# 3        0
# 4        1

# %%
df_train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# C              0
# Q              0
# S              0
# female         0
# male           0
# Salutation     0
# Ticket_Lett    0
# Ticket_Len     0
# Cabin_Lett     0
# FamilySize     0
# IsAlone        0
# dtype: int64

# %%
df_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# C                uint8
# Q                uint8
# S                uint8
# female           uint8
# male             uint8
# Salutation     float64
# Ticket_Lett      int64
# Ticket_Len       int64
# Cabin_Lett       int64
# FamilySize       int64
# IsAlone          int64
# dtype: object

# %%
df_train.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.031562 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.076673 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.317101  0.083081  0.018443
# Age             0.031562 -0.076673 -0.317101  1.000000 -0.230486 -0.188181
# SibSp          -0.057527 -0.035322  0.083081 -0.230486  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.188181  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.083573  0.159651  0.216225
# C              -0.001205  0.168240 -0.243292  0.034482 -0.059528 -0.011069
# Q              -0.033606  0.003650  0.221009  0.012061 -0.026354 -0.081228
# S               0.022148 -0.155660  0.081720 -0.045322  0.070941  0.063036
# female         -0.042939  0.543351 -0.131900 -0.088140  0.114631  0.245489
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 18 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Fare           891 non-null float64
# C              891 non-null uint8
# Q              891 non-null uint8
# S              891 non-null uint8
# female         891 non-null uint8
# male           891 non-null uint8
# Salutation     891 non-null float64
# Ticket_Lett    891 non-null int64
# Ticket_Len     891 non-null int64
# Cabin_Lett     891 non-null int64
# FamilySize     891 non-null int64
# IsAlone        891 non-null int64
# dtypes: float64(3), int64(10), uint8(5)
# memory usage: 94.9 KB

# %%
pd.get_dummies(df_test['Sex'])
df_sex=pd.get_dummies(df_test['Sex'])
df_sex.head()
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       0     1
# 3       0     1
# 4       1     0

# %%
#Embarked(乗船場所)もダミー変数化
pd.get_dummies(df_test['Embarked'])
df_embarked=pd.get_dummies(df_test['Embarked'])

df_embarked.head()
# Out:
#    C  Q  S
# 0  0  1  0
# 1  0  0  1
# 2  0  1  0
# 3  0  0  1
# 4  0  0  1

# %%
df_test=pd.concat([df_test,df_embarked],axis=1)
df_4 = df_test.drop('Embarked', axis=1)
df_test=df_4

# %%
df_test=pd.concat([df_test,df_sex],axis=1)
df_3 = df_test.drop('Sex', axis=1)
df_test=df_3
df_test
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
combine = [df_test]
for df_test in combine:
    df_test['Salutation'] = df_test.Name.str.extract(' ([A-Za-z]+)\.', expand=False)
for df_test in combine:
    df_test['Salutation'] = df_test['Salutation'].replace(['Lady', 'Countess','Capt', 'Col',\
         'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')

    df_test['Salutation'] = df_test['Salutation'].replace('Mlle', 'Miss')
    df_test['Salutation'] = df_test['Salutation'].replace('Ms', 'Miss')
    df_test['Salutation'] = df_test['Salutation'].replace('Mme', 'Mrs')
    del df_test['Name']
Salutation_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}

for df_test in combine:
    df_test['Salutation'] = df_test['Salutation'].map(Salutation_mapping)
    df_test['Salutation'] = df_test['Salutation'].fillna(0)

for df_test in combine:
        df_test['Ticket_Lett'] = df_test['Ticket'].apply(lambda x: str(x)[0])
        df_test['Ticket_Lett'] = df_test['Ticket_Lett'].apply(lambda x: str(x))
        df_test['Ticket_Lett'] = np.where((df_test['Ticket_Lett']).isin(['1', '2', '3', 'S', 'P', 'C', 'A']), test['Ticket_Lett'],
                                   np.where((df_test['Ticket_Lett']).isin(['W', '4', '7', '6', 'L', '5', '8']),
                                            '0', '0'))
        df_test['Ticket_Len'] = df_test['Ticket'].apply(lambda x: len(x))
        del df_test['Ticket']
df_test['Ticket_Lett']=df_test['Ticket_Lett'].replace("1",1).replace("2",2).replace("3",3).replace("0",0).replace("S",3).replace("P",0).replace("C",3).replace("A",3) 

for df_test in combine:
        df_test['Cabin_Lett'] = df_test['Cabin'].apply(lambda x: str(x)[0])
        df_test['Cabin_Lett'] = df_test['Cabin_Lett'].apply(lambda x: str(x))
        df_test['Cabin_Lett'] = np.where((df_test['Cabin_Lett']).isin(['T', 'H', 'G', 'F', 'E', 'D', 'C', 'B', 'A']),test['Cabin_Lett'],
                                   np.where((df_test['Cabin_Lett']).isin(['W', '4', '7', '6', 'L', '5', '8']),
                                            '0','0'))        
        del df_test['Cabin']
df_test['Cabin_Lett']=df_test['Cabin_Lett'].replace("A",1).replace("B",2).replace("C",1).replace("0",0).replace("D",2).replace("E",2).replace("F",1).replace("G",1) 

df_test["FamilySize"] = df_train["SibSp"] + df_train["Parch"] + 1

for df_test in combine:
    df_test['IsAlone'] = 0
    df_test.loc[test['FamilySize'] == 1, 'IsAlone'] = 1
    
df_test_data = df_test.values
x_test = df_test_data[:, 1:]

# %%
df_test
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch      Fare  C  Q  S  female  male  \
# 0            892       3  34.5      0      0    7.8292  0  1  0       0     1
# 1            893       3  47.0      1      0    7.0000  0  0  1       1     0
# 2            894       2  62.0      0      0    9.6875  0  1  0       0     1
# 3            895       3  27.0      0      0    8.6625  0  0  1       0     1
# 4            896       3  22.0      1      1   12.2875  0  0  1       1     0
# 5            897       3  14.0      0      0    9.2250  0  0  1       0     1
# 6            898       3  30.0      0      0    7.6292  0  1  0       1     0
# 7            899       2  26.0      1      1   29.0000  0  0  1       0     1
# 8            900       3  18.0      0      0    7.2292  1  0  0       1     0
# 9            901       3  21.0      2      0   24.1500  0  0  1       0     1
# 10           902       3   NaN      0      0    7.8958  0  0  1       0     1
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 17 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Fare           417 non-null float64
# C              418 non-null uint8
# Q              418 non-null uint8
# S              418 non-null uint8
# female         418 non-null uint8
# male           418 non-null uint8
# Salutation     418 non-null int64
# Ticket_Lett    418 non-null int64
# Ticket_Len     418 non-null int64
# Cabin_Lett     418 non-null object
# FamilySize     418 non-null int64
# IsAlone        418 non-null int64
# dtypes: float64(2), int64(9), object(1), uint8(5)
# memory usage: 41.3+ KB

# %%
train_data = df_train.values
x = train_data[:, 2:] # Pclass以降の変数
y  = train_data[:, 1]  # 正解データ

# %%
df_test["Age"].fillna(df_test.Age.mean(), inplace=True)
df_test["Fare"].fillna(df_test.Fare.mean(), inplace=True)

df_test["Salutation"].fillna(df_test.Fare.mean(), inplace=True)

# %%
df_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# C                uint8
# Q                uint8
# S                uint8
# female           uint8
# male             uint8
# Salutation     float64
# Ticket_Lett      int64
# Ticket_Len       int64
# Cabin_Lett       int64
# FamilySize       int64
# IsAlone          int64
# dtype: object

# %%
df_test.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# C                uint8
# Q                uint8
# S                uint8
# female           uint8
# male             uint8
# Salutation       int64
# Ticket_Lett      int64
# Ticket_Len       int64
# Cabin_Lett      object
# FamilySize       int64
# IsAlone          int64
# dtype: object

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 17 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Age            418 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Fare           418 non-null float64
# C              418 non-null uint8
# Q              418 non-null uint8
# S              418 non-null uint8
# female         418 non-null uint8
# male           418 non-null uint8
# Salutation     418 non-null int64
# Ticket_Lett    418 non-null int64
# Ticket_Len     418 non-null int64
# Cabin_Lett     418 non-null object
# FamilySize     418 non-null int64
# IsAlone        418 non-null int64
# dtypes: float64(2), int64(9), object(1), uint8(5)
# memory usage: 41.3+ KB

# %%
test_data = df_test.values
x_test = test_data[:, 1:]
from sklearn.ensemble import RandomForestClassifier

# %%
random_forest=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=25, max_features='auto', max_leaf_nodes=None,
            min_samples_leaf=1, min_samples_split=15,
            min_weight_fraction_leaf=0.0, n_estimators=51, n_jobs=4,
            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
random_forest.fit(x, y)
Y_pred = random_forest.predict(x_test)
random_forest.score(x,y)
acc_random_forest = round(random_forest.score(x,y) * 100, 2)
acc_random_forest
# Out:
# 88.89

# %%
import csv
with open("predict_result_data6.csv", "w") as f:
    writer = csv.writer(f, lineterminator='\n')
    writer.writerow(["PassengerId", "Survived"])
    for pid, survived in zip(test_data[:,0].astype(int), Y_pred.astype(int)):
        writer.writerow([pid, survived])
